# %% [markdown]
# # Importation des données iris

# %% [markdown]
# # Visualisation des différentes variables du jeu de données

# %% [markdown]
# # Visualisation des différentes espèces de plantes

# %% [markdown]
# # Visualisation de la relation entre Petal et Sepal

# %% [markdown]
# # Boxplot de la longueur des pétales pour chaque espèce de plante

# %% [markdown]
# # Diagramme en violon de la distribution de la largeur des sépales par espèce de plante

# %% [markdown]
# # Diagramme en camembert des effectifs pour chaque espèce de plante

# %% [markdown]
# # Séparer le jeu de données

# %% [markdown]
# # Entraînement d'un modèle d'arbre de décision pour résoudre le problème de classification

# %% [markdown]
# # Calculer la logloss

# %% [markdown]
# # Obtenir une matrice de confusion

# %% [markdown]
# # Sauvegarde du modèle
